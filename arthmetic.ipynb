# %%
num 1=24
num 2=24
print(num1+num2)

# %%
str1="helo"
str2="world"
print(str1+""+str2)
# Out:
# heloworld

# %%
boolvalue01 = True
boolvalue02=False
print(boolvalue01 + True)

# %%
income_tax = 1000
retirement_contribution = 500
professional_tax = 200
gross_salary = 100000
net_salary = gross_salary - (income_tax + retirement_contribution + professional_tax)
print("Net Salary:", net_salary)
# Out:
# Net Salary: 98300
