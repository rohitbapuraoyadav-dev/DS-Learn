# %%
# This application is for understanding exception handling in Python. It demonstrates how to catch and handle exceptions that may occur during the execution of a program.

# %%
numvalue = int(input("Enter a number: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 numvalue = int(input("Enter a number: "))
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
numvalue = input("Please enter a number: ")
num1 = int(numvalue)
num2 = int(input("Please enter another number: "))

result = num1 / num2
print("The result of the division is:", result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 numvalue = input("Please enter a number: ")
#       2 num1 = int(numvalue)
#       3 num2 = int(input("Please enter another number: "))
#       4
# ----> 5 result = num1 / num2
#       6 print("The result of the division is:", result)
#
# ZeroDivisionError: division by zero

# %%
try :
    num1=int(input("Please enter a number: "))
    num2=int(input("Please enter another number: "))
    result=num1/num2
    print("The result of the division is:", result)
except ValueError:
    print("Invalid input. Please enter a valid integer.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Invalid input. Please enter a valid integer.

# %%
try:
    num1=int(input("Please enter a number: "))
    num2=int(input("Please enter another number: "))
    try:
    except ValueError:
    print("Invalid input. Please enter a valid integer.")
    result=num1/num2
    print("The result of the division is:", result)

except ZeroDivisionError:
    print("Error: Division by zero is not allowed."

    num2=int(input("Please enter another number: "))
try :
except ValueError:
    print("Invalid input. Please enter a valid integer.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

    result=num1/num2
# Out:
#   Cell In[14], line 1
#     num1=int(input("Please enter a number: "))
#     ^
# IndentationError: unexpected indent

# %%
#this is the example of nested try except block and finally block. The outer try block handles the input conversion, while the inner try block handles the division operation. The finally block ensures that cleanup code is executed regardless of whether an exception occurred or not.

try :                            #here I encountered indentation error
    num1=int(input("Please enter a number: "))
    num2=int(input("Please enter another number: "))
    try: 
        result=num1/num2
        print("The result of the division is:", result)
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
except ValueError:
        print("Invalid input. Please enter a valid integer.")
finally:
        print("Execution completed.") #close resources,cleanup etc.
print("This is the end of the program .")
# Out:
# The result of the division is: 2.0
# Execution completed.
# This is the end of the program .
