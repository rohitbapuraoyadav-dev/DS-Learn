# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitbapuraoyadav-dev/DS-Learn/blob/main/Googlecollab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print welcome to python
# Out:
#   File "/tmp/ipykernel_849/3564030053.py", line 1
#     print welcome to python
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("hey sahuiiiilllllll")
# Out:
# hey sahuiiiilllllll

# %%
print ("welcome to python")
# Out:
# welcome to python

# %%
print ("the second day of traning starts")
# Out:
# the second day of traning starts

# %% [markdown]
# # New Section
