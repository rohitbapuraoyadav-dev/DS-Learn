# %%
class Bank:
    account_no = 100000
    def __inti__(self,acc_no , name ,bal ) :
        Bank.account_no +=1
        self.acc_no = Bank.account_no
        self.name = name
        self.bal = bal

    def deposit(self ,)

    def withdraw()

    def showbankdetails(self):
        return("Account no:", self.acc_no ,"Accounter's Name:", self.name ,"ACcount balance :", self.bal)

    class Savings(Bank):
        min_balance=2000

        def withdraw(self , amount):
            if amount<=0:
                raise ValueError("Amount cannot be -ve")
            elif bal-amount<=Savings.min_balance :    
               raise ValueError("Cant Withdraw :")
            else:
                 self.bal= self.bal-amount
# Out:
#   Cell In[9], line 9
#     def deposit
#                 ^
# SyntaxError: expected '('

# %%
#creating objects
savobj = Savings(101,10000)

#Calling methods using objects
savobj.show_balance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #creating objects
# ----> 2 savobj = Savings(101,10000)
#       3
#       4 #Calling methods using objects
#       5 savobj.show_balance()
#
# NameError: name 'Savings' is not defined
