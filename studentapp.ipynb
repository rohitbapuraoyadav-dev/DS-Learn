# %%
student_rollno = 65
student_name = "Rohan"
student_marks_s1 = 78
student_marks_s2 = 80
student_marks_s3 = 90
average_marks = (student_marks_s1 + student_marks_s2 + student_marks_s3) / 3
print ("student rollno :",student_rollno)
print ("student name :",student_name)
print ("student average marks :",average_marks)
# Out:
# student rollno : 65
# student name : Rohan
# student average marks : 82.66666666666667

# %%
student2_rollno = 56
student2_name = "Mohan"
student2_marks_s1 = 88
student2_marks_s2 = 98
student2_marks_s3 = 79
student2_average_marks = (student2_marks_s1 + student2_marks_s2 + student2_marks_s3) / 3
print ("student rollno :",student2_rollno)
print ("student name :",student2_name)
print ("student average marks :",student2_average_marks)
# Out:
# student rollno : 56
# student name : Mohan
# student average marks : 88.33333333333333

# %%
average_marks > student2_average_marks
# Out:
# False

# %%
average_marks < student2_average_marks
# Out:
# True
