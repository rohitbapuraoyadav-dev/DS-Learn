# %%
#Notebook for learning Datetime Type

# %%
from datetime import datetime , timedelta
datevar = datetime.now()
print(datevar)

print(datetime.today())
print(datetime(2026, 7 ,27))

print("Year:", datevar.year)
print("MOnth:", datevar.month)
print("Day:", datevar.day)
print("Week day:", datevar.weekday())

datevar2 = datetime(2026, 7 ,31)
print(datevar2-datevar)
print(datevar + timedelta(hours=3))

#convert from string to date object

datevar3 = datetime.strptime("15-AUgust-2026", '%d-%m-%Y')
print(datevar3 - datevar)

#convert from date object to string

#print("Independence day" +datetime.strptime)
#datevar3.
# Out:
# 2026-07-27 07:03:53.467987
# 2026-07-27 07:03:53.468234
# 2026-07-27 00:00:00
# Year: 2026
# MOnth: 7
# Day: 27
# Week day: 0
# 3 days, 16:56:06.532013
# 2026-07-27 10:03:53.467987
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 19
#      15 print(datevar + timedelta(hours=3))
#      16
#      17 #convert from string to date object
#      18
# ---> 19 datevar3 = datetime.strptime("15-AUgust-2026", '%d-%m-%Y')
#      20 print(datevar3 - datevar)
#      21
#      22 #convert from date object to string
#
# File c:\Program Files\Python313\Lib\_strptime.py:789, in _strptime_datetime(cls, data_string, format)
#     786 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     787     """Return a class cls instance based on the input string and the
#     788     format string."""
# --> 789     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     790     tzname, gmtoff = tt[-2:]
#     791     args = tt[:6] + (fraction,)
#
# File c:\Program Files\Python313\Lib\_strptime.py:555, in _strptime(data_string, format)
#     553 found = format_regex.match(data_string)
#     554 if not found:
# --> 555     raise ValueError("time data %r does not match format %r" %
#     556                      (data_string, format))
#     557 if len(data_string) != found.end():
#     558     raise ValueError("unconverted data remains: %s" %
#     559                       data_string[found.end():])
#
# ValueError: time data '15-AUgust-2026' does not match format '%d-%m-%Y'
