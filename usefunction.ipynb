# %%
number = -1234
print(abs(number))  # Output: 1234
# Out:
# 1234

# %%
number_value = input("Enter a number: ")
number = int(number_value)
number = abs(number_value)
print (abs(number))  # Output: 1234
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 number_value = input("Enter a number: ")
# ----> 2 number = int(number_value)
#       3 number = abs(number_value)
#       4 print (abs(number))  # Output: 1234
#
# ValueError: invalid literal for int() with base 10: ''

# %%
salary_ = input("Enter your salary: ")
salary = abs(float(salary_))
print(salary
# Out:
# 233.0

# %%
num1 = 123
num2 = 333
num3 = 324
num4 = 123
print(min(num1, num2, num3, num4))
print(max(num1, num2, num3, num4))

num4 = 3
print(pow(num1, num4))

message = "Hello, World!"
print(len(message))
# Out:
# 123
# 333
# 1860867
# 13

# %%
print (chr(65))  # Output: A
# Out:
# A

# %%
boolean_value = input("Enter a boolean value (True/False): ")
bool_value = bool(boolean_value)
print(bool_value)  # Output: True or False based on user input
# Out:
# True

# %%
n = 44
binary_representation = bin(n)
print(binary_representation)  # Output: 0b101100
# Out:
# 0b101100

# %%
number = input("Enter a number: ")
integer_value = int(float(number))
print(integer_value)  # Output: The integer value of the input number
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 number = input("Enter a number: ")
#       2 integer_value = int(float(number))
#       3 print(integer_value)  # Output: The integer value of the input number
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
# ...
