# %%
a= 34
b= 14.5
print("addition",a+b)
print ("subtraction",a-b)
print ("modulus",a%b)
print("exponential",a**b)
# Out:
# addition 48.5
# subtraction 19.5
# modulus 5.0
# exponential 1.608586046384492e+22
